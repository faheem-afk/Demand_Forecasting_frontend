# %%
import pandas as pd
df = pd.read_csv("df_predictions.csv")
print("Shape:", df.shape)
print("Columns:", df.columns.tolist())
print("Period values:", df['period'].unique())
print("Sample:\n", df.head(3))
print("Week range:", df['week_number'].min(), "to", df['week_number'].max())
print("Cities:", df['city_name'].nunique(), "—", df['city_name'].unique()[:5])
print("Meals:", df['meal_name'].nunique(), "—", df['meal_name'].unique()[:5])
# Out:
# Shape: (528574, 8)
# Columns: ['period', 'week_number', 'num_orders', 'current_week', 'meal_name', 'city_name', 'meal_category', 'meal_type']
# Period values: ['past' 'Future']
# Sample:
#    period  week_number  num_orders  current_week               meal_name  \
# 0   past           27       256.0           146  Apple and Raisin Bread
# 1   past           28       122.0           146  Apple and Raisin Bread
# 2   past           29       163.0           146  Apple and Raisin Bread
#
#     city_name meal_category meal_type
# 0  Aldershade         Other   dessert
# 1  Aldershade         Other   dessert
# 2  Aldershade         Other   dessert
# Week range: 1 to 157
# Cities: 76 — ['Aldershade' 'Amberhill' 'Ashenport' 'Aspenfall' 'Brackenbury']
# Meals: 51 — ['Apple and Raisin Bread' 'Baked Apple with Cinnamon'
#  'Baked Potato with Chives' 'Barley and Mushroom Risotto'
#  'Basil and Tomato Soup']
